# %%
#This code takes the original data, the prediction of nns and the BMS, computes the rmse and mae for interpolation and extrapolation
#and saves everything into a dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure
import seaborn as sns
import matplotlib.gridspec as gridspec
import ast
import sys
sys.path.append('../no_degeneracy/')
sys.path.append('../no_degeneracy/Prior/')
from mcmc import *
from parallel import *
from fit_prior import read_prior_par
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
def clean_index(dataframe):
    dataframe.set_index('Unnamed: 0', inplace=True)
    dataframe.index.name = None
    dataframe= dataframe.reset_index(drop=True)
    return dataframe

def add_bms_pred(dataframe, bms_trace, number_param):
    VARS = ['x1',]
    x = dataframe[[c for c in VARS]].copy()
    y=dataframe.y

    if number_param==10:
        prior_par = read_prior_par('../no_degeneracy/Prior/final_prior_param_sq.named_equations.nv1.np10.2017-10-18 18:07:35.089658.dat')
    elif number_param==20:
        prior_par = read_prior_par('../no_degeneracy/Prior/final_prior_param_sq.named_equations.nv1.np20.maxs200.2024-05-10 162907.551306.dat')

    #mdl model
    minrow = bms_trace[bms_trace.H == min(bms_trace.H)].iloc[0]
    minH, minexpr, minparvals = minrow.H, minrow.expr, ast.literal_eval(minrow.parvals)

    t = Tree(
        variables=list(x.columns),
        parameters=['a%d' % i for i in range(number_param)],
        x=x, y=y,
        prior_par=prior_par,
        max_size=200,
        from_string=minexpr,
    )

    t.set_par_values(deepcopy(minparvals))

    dplot = deepcopy(dataframe)
    dplot['ybms'] = t.predict(x)
    dinterpolate=deepcopy(dplot)


    return dinterpolate

# %%
#Read NN and BMS data
#resolutions={'0.5x':'0.1', '1x':'0.05', '2x': '0.025', '4e-3x':'0.004' }
#resolution='1x'

#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
resolution='1x' #'0.5x', '1x', '2x', '4e-3'
resolutions_interp={'0.5x':'0.02', '1x':'0.01' , '2x': '0.005' , '4e-3x':'0.0008' }

resolutions={'0.5x':'0.1', '1x':'0.05' , '2x': '0.025' , '4e-3x':'0.004' }
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~


functions=['tanh', 'leaky_ReLU'] #tanh, leaky_ReLU
realizations=2
N=9
sigmas=[0.0, 0.02, 0.04,0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.20]


runid=0
NPAR=10 #10, 20
steps=50000


rmse_nn_train=[];rmse_nn_test=[]
rmse_mdl_train=[];rmse_mdl_test=[]

mae_nn_train=[];mae_nn_test=[]
mae_mdl_train=[];mae_mdl_test=[]

n_index=[];r_index=[];sigma_index=[];function_index=[]

#Put mae and rmse of each simulation (on nn and bms) in a dataframe
for function in functions:
    for sigma in sigmas:
        for realization in range(realizations+1):
            
            #Read NN data
            #file_model='NN_no_overfit_' + function + '_sigma_' + str(sigma) + '_r_' + str(r) + '.csv'
            #file_model_hr='NN_no_overfit_' + function + '_sigma_' + str(sigma) + '_r_' + str(r) + '_res_0.01.csv'

            #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            file_model='NN_no_overfit_' + function + '_sigma_' + str(sigma) + '_r_' + str(realization) + '.csv'
            model_d='../../data/nns/' + resolution + '_resolution/approximation/' + file_model
            
            
            file_model_hr='NN_no_overfit_' + function + '_sigma_' + str(sigma) + '_r_' + str(realization) + '_res_' + \
            resolutions_interp[resolution] + '.csv'
            model_dhr='../../data/nns/' + resolution + '_resolution/inter_extrapolation/' + file_model_hr
            #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
            
            #model_dhr='../data/inter_extrapolate_nns/' + file_model_hr
            dhr=pd.read_csv(model_dhr)

            #model_d='../data/1x_resolution/trained_nns/' + file_model
            d=pd.read_csv(model_d)
            

            for n in range(N+1):
                n_index.append(n);r_index.append(realization);sigma_index.append(sigma);function_index.append(function)

                #High resolution dataset
                dnhr=dhr[dhr['rep']==n]
                dnhr=dnhr[(dnhr['x1']>=-2.0) & (dnhr['x1']<=2.0)]
                dnhr=clean_index(dnhr)
                #-------------------------------------------------------------
                #train_value=1.0
                #train_border_row=dnhr[(dnhr['x1']<=1.0) & (dnhr['x1']>=0.99)] 
                #print(train_border_row)
                #train_size=train_border_row.index[0]
                #print(train_size)
                #-------------------------------------------------------------

                #Get interpolation/extrapolation border
                #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
                n_points=int(len(dhr.index)/10)
                train_fraction=3/4;train_size=int(n_points*train_fraction)
                print(train_size)
                #~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

                #Read BMS data
                filename='BMS_'+function+'_n_'+str(n)+'_sigma_'+str(sigma)+ '_r_' + str(realization) + '_res_'+ resolutions[resolution] +  '_trace_'+str(steps)+'_prior_'+str(NPAR)+ '.csv'
        
                #trace=pd.read_csv('../../data/MSTraces/1x_resolution/' + filename, sep=';', header=None, names=['t', 'H', 'expr', 'parvals', 'kk1', 'kk2','kk3'])
                trace_path='../../data/MSTraces/' + resolution + '_resolution/'
                trace=pd.read_csv(trace_path + filename, sep=';', header=None, names=['t', 'H', 'expr', 'parvals', 'kk1', 'kk2','kk3'])
                dinterpolate=add_bms_pred(dnhr, trace, NPAR)

                #Remove approximation points
                #-------------------------------------------------------------
                dinterpolate=dinterpolate.round({'x1':2})
                dn=d[d['rep']==n]
                dn.set_index('Unnamed: 0', inplace=True)
                dn.index.name = None
                dn=dn.reset_index(drop=True)
                dn=dn.round({'x1':2})
                dinterpolate=dinterpolate[-dinterpolate['x1'].isin(dn['x1'].tolist() )] #cross dataframes to get only high resolution points
                #-------------------------------------------------------------

                display(dinterpolate.loc[train_size-1])
            
                print("interpolation")
                display(dinterpolate.loc[train_size -5 : train_size - 1])
                
                print("extrapolation")
                display(dinterpolate.loc[train_size -1 : train_size + 4])
                
                #Errors
                #-----------------------------------------------------------------------------------------------------------------------
                #nns
                rmse_nn_train_i=root_mean_squared_error(dinterpolate.loc[:train_size-1]['ymodel'],dinterpolate.loc[:train_size -1]['y'])
                rmse_nn_train.append(rmse_nn_train_i)
                
                rmse_nn_test_i=root_mean_squared_error(dinterpolate.loc[train_size-1:]['ymodel'],dinterpolate.loc[train_size -1:]['y'])
                rmse_nn_test.append(rmse_nn_test_i)

                mae_nn_train_i=mean_absolute_error(dinterpolate.loc[:train_size-1]['ymodel'],dinterpolate.loc[:train_size -1]['y'])
                mae_nn_train.append(mae_nn_train_i)
            
                mae_nn_test_i=mean_absolute_error(dinterpolate.loc[train_size-1:]['ymodel'],dinterpolate.loc[train_size -1:]['y'])
                mae_nn_test.append(mae_nn_test_i)

                #bms
                try:
                    rmse_mdl_train_i=root_mean_squared_error(dinterpolate.loc[:train_size-1]['ybms'],dinterpolate.loc[:train_size-1]['y'])
                except ValueError:
                    rmse_mdl_train_i=np.inf
                rmse_mdl_train.append(rmse_mdl_train_i)

                try:
                    rmse_mdl_test_i=root_mean_squared_error(dinterpolate.loc[train_size-1:]['ybms'],dinterpolate.loc[train_size-1:]['y'])
                except ValueError:
                    rmse_mdl_test_i=np.inf
                    
                rmse_mdl_test.append(rmse_mdl_test_i)

                try:
                    mae_mdl_train_i=mean_absolute_error(dinterpolate.loc[:train_size-1]['ybms'],dinterpolate.loc[:train_size -1]['y'])
                except ValueError:
                    mae_mdl_train_i=np.inf
                    
                mae_mdl_train.append(mae_mdl_train_i)

                try:
                    mae_mdl_test_i=mean_absolute_error(dinterpolate.loc[train_size-1:]['ybms'],dinterpolate.loc[train_size -1:]['y'])
                except ValueError:
                    mae_mdl_test_i=np.inf
                
                mae_mdl_test.append(mae_mdl_test_i)
                #-----------------------------------------------------------------------------------------------------------------------              
             

              
#Save all in a dataframe      
errors_df=pd.DataFrame({'sigma':sigma_index, 'function':function_index, 'mae_nn_interp.':mae_nn_train, 'mae_nn_extrap.':mae_nn_test, 
                        'mae_mdl_interp.':mae_mdl_train, 'mae_mdl_extrap.':mae_mdl_test, 'rmse_nn_interp.':rmse_nn_train, 
                        'rmse_nn_extrap.': rmse_nn_test, 'rmse_mdl_interp.':rmse_mdl_train, 'rmse_mdl_extrap.': rmse_mdl_test, 
                        'n':n_index, 'r': r_index})
errors_df.to_csv('../../data/errors_interpolation_' + resolution + '.csv')
display(errors_df)
# Out:
#       x1         y  rep    ymodel
# 299  1.0  0.987559  0.0  1.010395
# 299
# <lambdifygenerated-14035>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + x1**x1
# <lambdifygenerated-14036>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + x1**x1
# <lambdifygenerated-14045>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*x1)))**x1
# <lambdifygenerated-14047>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*x1**x1)))**x1
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14048>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*x1**x1)))**x1
# <lambdifygenerated-14049>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1)**x1)))**x1
# <lambdifygenerated-14050>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1)**x1)))**x1
# <lambdifygenerated-14051>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1**2)**x1)))**x1
# <lambdifygenerated-14052>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1**2)**x1)))**x1
# <lambdifygenerated-14053>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(2*x1**2)**x1)))**x1
# <lambdifygenerated-14054>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(2*x1**2)**x1)))**x1
# <lambdifygenerated-14055>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1*(_a4_ + x1))**x1)))**x1
# <lambdifygenerated-14056>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1*(_a4_ + x1))**x1)))**x1
# <lambdifygenerated-14057>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1*(_a4_ + 1))**x1)))**x1
# <lambdifygenerated-14058>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1*(_a4_ + 1))**x1)))**x1
# <lambdifygenerated-14059>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1*(_a4_ + 1))**x1)))**x1
# <lambdifygenerated-14060>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1*(_a4_ + 1))**x1)))**x1
# <lambdifygenerated-14061>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14062>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(x1*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14063>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14064>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14065>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14066>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(x1 + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14067>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14068>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1*(_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14069>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (2*x1*(_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14070>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (2*x1*(_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1)))**x1
# <lambdifygenerated-14071>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1**2 + x1))**x1
# <lambdifygenerated-14072>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1**2 + x1))**x1
# <lambdifygenerated-14073>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(2*x1**2 + x1))**x1
# <lambdifygenerated-14074>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(2*x1**2 + x1))**x1
# <lambdifygenerated-14075>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1*(x1**2 + x1) + x1))**x1
# <lambdifygenerated-14076>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1*(x1**2 + x1) + x1))**x1
# <lambdifygenerated-14077>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1*(_a7_*x1 + x1) + x1))**x1
# <lambdifygenerated-14078>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1*(_a7_*x1 + x1) + x1))**x1
# <lambdifygenerated-14079>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1*(_a7_*x1 + x1) + x1))**x1
# <lambdifygenerated-14080>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1*(_a7_*x1 + x1) + x1))**x1
# <lambdifygenerated-14081>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1*(_a6_ + _a7_*x1) + x1))**x1
# <lambdifygenerated-14082>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1*(_a6_ + _a7_*x1) + x1))**x1
# <lambdifygenerated-14083>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(x1)))**x1
# <lambdifygenerated-14084>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(x1)))**x1
# <lambdifygenerated-14085>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(x1**2)))**x1
# <lambdifygenerated-14086>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(x1**2)))**x1
# <lambdifygenerated-14087>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(x1**2)))**x1
# <lambdifygenerated-14088>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(x1**2)))**x1
# <lambdifygenerated-14089>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(x1**2)))**x1
# <lambdifygenerated-14090>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(x1**2)))**x1
# <lambdifygenerated-14091>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(_a0_*x1)))**x1
# <lambdifygenerated-14092>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(x1 + (_a6_ + _a7_*x1)*cos(_a0_*x1)))**x1
# <lambdifygenerated-14093>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(_a5_ + (_a6_ + _a7_*x1)*cos(_a0_*x1)))**x1
# <lambdifygenerated-14094>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(_a5_ + (_a6_ + _a7_*x1)*cos(_a0_*x1)))**x1
# <lambdifygenerated-14095>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(_a5_ + (_a6_ + _a7_*x1)*cos(_a0_*x1)))**_a1_
# <lambdifygenerated-14097>:2: RuntimeWarning: invalid value encountered in power
#   return _a0_ + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(_a5_ + (_a6_ + _a7_*x1)*cos(_a0_*x1)))**_a1_
# <lambdifygenerated-14101>:2: RuntimeWarning: invalid value encountered in power
#   return _a0_ + ((_a2_ + tanh(_a3_*cosh(_a2_*(_a4_ + x1/_a3_))**x1))*(_a5_ + (_a6_ + _a7_*x1)*cos(_a0_*x1)))**_a1_
# x1        0.990000
# y         0.987001
# rep       0.000000
# ymodel    1.009174
# ybms      0.986299
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.985299  0.0  1.005428  0.985088
# 296  0.97  0.985870  0.0  1.006691  0.985502
# 297  0.98  0.986437  0.0  1.007940  0.985906
# 298  0.99  0.987001  0.0  1.009174  0.986299
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.987001  0.0  1.009174  0.986299
# 300  1.01  0.988112  0.0  1.011602  0.987054
# 301  1.02  0.988659  0.0  1.012796  0.987416
# 302  1.03  0.989198  0.0  1.013976  0.987767
# 303  1.04  0.989730  0.0  1.015144  0.988108
#       x1         y  rep    ymodel
# 299  1.0  0.052813  1.0  0.038976
# 299
# <lambdifygenerated-14115>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + tan(2*x1 + x1**x1)
# <lambdifygenerated-14116>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + tan(2*x1 + x1**x1)
# <lambdifygenerated-14131>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + tan(_a6_**(_a0_ + x1) + x1 + tan(tanh(x1**2)/x1))
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# x1        0.990000
# y         0.053831
# rep       1.000000
# ymodel    0.040563
# ybms      0.048308
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.056974  1.0  0.045547  0.054188
# 296  0.97  0.055911  1.0  0.043848  0.052266
# 297  0.98  0.054863  1.0  0.042186  0.050307
# 298  0.99  0.053831  1.0  0.040563  0.048308
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.053831  1.0  0.040563  0.048308
# 300  1.01  0.051809  1.0  0.037425  0.044182
# 301  1.02  0.050818  1.0  0.035908  0.042050
# 302  1.03  0.049839  1.0  0.034425  0.039871
# 303  1.04  0.048871  1.0  0.032975  0.037641
# <lambdifygenerated-14185>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - x1**x1)**2)
# <lambdifygenerated-14186>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - x1**x1)**2)
# <lambdifygenerated-14189>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - (x1**(2*x1))**x1)**2)
# <lambdifygenerated-14190>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - (x1**(2*x1))**x1)**2)
# <lambdifygenerated-14193>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a3_*x1)**(2*x1))**x1)**2)
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14194>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a3_*x1)**(2*x1))**x1)**2)
# <lambdifygenerated-14195>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**x1)**2)
# <lambdifygenerated-14199>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(x1**x1))**2)
# <lambdifygenerated-14200>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(x1**x1))**2)
# <lambdifygenerated-14201>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**x1))**2)
# <lambdifygenerated-14201>:2: RuntimeWarning: overflow encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**x1))**2)
# <lambdifygenerated-14201>:2: RuntimeWarning: overflow encountered in square
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**x1))**2)
# <lambdifygenerated-14201>:2: RuntimeWarning: overflow encountered in multiply
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**x1))**2)
# <lambdifygenerated-14201>:2: RuntimeWarning: invalid value encountered in sin
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**x1))**2)
# <lambdifygenerated-14207>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(x1**2 + x1)))**2)
# <lambdifygenerated-14211>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(2*x1**2)))**2)
# <lambdifygenerated-14213>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - (_a0_*_a3_)**(2*x1))**2)
# <lambdifygenerated-14215>:2: RuntimeWarning: overflow encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-x1**4 + x1**2)))**2)
# <lambdifygenerated-14215>:2: RuntimeWarning: overflow encountered in square
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-x1**4 + x1**2)))**2)
# <lambdifygenerated-14215>:2: RuntimeWarning: invalid value encountered in sin
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-x1**4 + x1**2)))**2)
# <lambdifygenerated-14216>:2: RuntimeWarning: overflow encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-x1**4 + x1**2)))**2)
# <lambdifygenerated-14216>:2: RuntimeWarning: overflow encountered in square
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-x1**4 + x1**2)))**2)
# <lambdifygenerated-14216>:2: RuntimeWarning: invalid value encountered in sin
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-x1**4 + x1**2)))**2)
#       x1         y  rep   ymodel
# 299  1.0  0.278053  2.0  0.30298
# 299
# <lambdifygenerated-14219>:2: RuntimeWarning: invalid value encountered in log
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(x1) + x1**2)))**2)
# <lambdifygenerated-14220>:2: RuntimeWarning: invalid value encountered in log
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(x1) + x1**2)))**2)
# <lambdifygenerated-14223>:2: RuntimeWarning: invalid value encountered in log
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_*x1) + x1**2)))**2)
# <lambdifygenerated-14224>:2: RuntimeWarning: invalid value encountered in log
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_*x1) + x1**2)))**2)
# <lambdifygenerated-14225>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14225>:2: RuntimeWarning: overflow encountered in power
#   return x1*sin(x1**3*(-x1 - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14227>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1**3*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14227>:2: RuntimeWarning: overflow encountered in power
#   return x1*sin(x1**3*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14229>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*x1**(2*x1)*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14230>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*x1**(2*x1)*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14231>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(2*x1)**(2*x1)*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14232>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(2*x1)**(2*x1)*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14233>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(3*x1)**(2*x1)*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14234>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(3*x1)**(2*x1)*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2)
# <lambdifygenerated-14235>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a7_ + 2*x1)**(2*x1))
# <lambdifygenerated-14236>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a7_ + 2*x1)**(2*x1))
# <lambdifygenerated-14237>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a7_ + 2*x1)**(2*x1))
# <lambdifygenerated-14238>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a7_ + 2*x1)**(2*x1))
# <lambdifygenerated-14239>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a7_ + x1 + x1**x1)**(2*x1))
# <lambdifygenerated-14240>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a7_ + x1 + x1**x1)**(2*x1))
# <lambdifygenerated-14241>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*x1))
# <lambdifygenerated-14242>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*x1))
# <lambdifygenerated-14243>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*x1))
# <lambdifygenerated-14244>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*x1))
# <lambdifygenerated-14245>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# <lambdifygenerated-14246>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(x1*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# <lambdifygenerated-14247>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(_a1_*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# <lambdifygenerated-14248>:2: RuntimeWarning: invalid value encountered in power
#   return x1*sin(_a1_*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# <lambdifygenerated-14249>:2: RuntimeWarning: invalid value encountered in power
#   return _a2_*sin(_a1_*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# <lambdifygenerated-14250>:2: RuntimeWarning: invalid value encountered in power
#   return _a2_*sin(_a1_*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# <lambdifygenerated-14251>:2: RuntimeWarning: invalid value encountered in power
#   return _a2_*sin(_a1_*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# <lambdifygenerated-14252>:2: RuntimeWarning: invalid value encountered in power
#   return _a2_*sin(_a1_*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# <lambdifygenerated-14253>:2: RuntimeWarning: invalid value encountered in power
#   return _a2_*sin(_a1_*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# <lambdifygenerated-14254>:2: RuntimeWarning: invalid value encountered in power
#   return _a2_*sin(_a1_*(-_a6_ - ((_a0_*_a3_)**(2*x1))**(exp(x1)**(-_a0_**3*log(_a5_**2) + x1**2)))**2*(_a0_**x1 + _a7_ + x1)**(2*_a0_))
# x1        0.990000
# y         0.276233
# rep       2.000000
# ymodel    0.297600
# ybms      0.272810
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.269935  2.0  0.280760  0.269370
# 296  0.97  0.272190  2.0  0.286491  0.270689
# 297  0.98  0.274284  2.0  0.292104  0.271824
# 298  0.99  0.276233  2.0  0.297600  0.272810
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.276233  2.0  0.297600  0.272810
# 300  1.01  0.279756  2.0  0.308243  0.274453
# 301  1.02  0.281355  2.0  0.313391  0.275160
# 302  1.03  0.282864  2.0  0.318424  0.275816
# 303  1.04  0.284293  2.0  0.323343  0.276436
#       x1        y  rep    ymodel
# 299  1.0  0.30785  3.0  0.306824
# 299
# <lambdifygenerated-14271>:2: RuntimeWarning: invalid value encountered in power
#   return exp((x1 - tanh(x1*x1**x1))/x1)
# <lambdifygenerated-14272>:2: RuntimeWarning: invalid value encountered in power
#   return exp((x1 - tanh(x1*x1**x1))/x1)
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14309>:2: RuntimeWarning: overflow encountered in power
#   return exp((x1 - tanh(x1*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/x1)
# <lambdifygenerated-14310>:2: RuntimeWarning: overflow encountered in power
#   return exp((x1 - tanh(x1*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/x1)
# <lambdifygenerated-14311>:2: RuntimeWarning: overflow encountered in power
#   return exp((x1 - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/x1)
# <lambdifygenerated-14311>:2: RuntimeWarning: overflow encountered in exp
#   return exp((x1 - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/x1)
# <lambdifygenerated-14312>:2: RuntimeWarning: overflow encountered in power
#   return exp((x1 - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/x1)
# <lambdifygenerated-14312>:2: RuntimeWarning: overflow encountered in exp
#   return exp((x1 - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/x1)
# <lambdifygenerated-14313>:2: RuntimeWarning: overflow encountered in power
#   return exp((_a2_ - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/x1)
# <lambdifygenerated-14314>:2: RuntimeWarning: overflow encountered in power
#   return exp((_a2_ - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/x1)
# <lambdifygenerated-14315>:2: RuntimeWarning: overflow encountered in power
#   return exp((_a2_ - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/_a4_)
# <lambdifygenerated-14316>:2: RuntimeWarning: overflow encountered in power
#   return exp((_a2_ - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/_a4_)
# <lambdifygenerated-14317>:2: RuntimeWarning: overflow encountered in power
#   return exp((_a2_ - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/_a4_)
# <lambdifygenerated-14318>:2: RuntimeWarning: overflow encountered in power
#   return exp((_a2_ - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/_a4_)
# <lambdifygenerated-14319>:2: RuntimeWarning: overflow encountered in power
#   return exp((_a2_ - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/_a4_)
# <lambdifygenerated-14320>:2: RuntimeWarning: overflow encountered in power
#   return exp((_a2_ - tanh(_a6_*((_a3_ + x1**3/_a5_)**2)**(_a4_ - sin(_a1_) + x1/_a1_)))/_a4_)
# x1        0.990000
# y         0.304404
# rep       3.000000
# ymodel    0.303320
# ybms      0.304060
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.293415  3.0  0.292399  0.292988
# 296  0.97  0.297183  3.0  0.296108  0.296754
# 297  0.98  0.300848  3.0  0.299748  0.300445
# 298  0.99  0.304404  3.0  0.303320  0.304060
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.304404  3.0  0.303320  0.304060
# 300  1.01  0.311180  3.0  0.310262  0.311063
# 301  1.02  0.314393  3.0  0.313633  0.314450
# 302  1.03  0.317484  3.0  0.316938  0.317761
# 303  1.04  0.320453  3.0  0.320179  0.320995
#       x1         y  rep    ymodel
# 299  1.0  0.965519  4.0  0.963527
# 299
# <lambdifygenerated-14347>:2: RuntimeWarning: invalid value encountered in power
#   return x1*(x1 + tanh(tanh(x1*(_a6_*x1**x1 + x1))/x1)) + x1
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14348>:2: RuntimeWarning: invalid value encountered in power
#   return x1*(x1 + tanh(tanh(x1*(_a6_*x1**x1 + x1))/x1)) + x1
# x1        0.990000
# y         0.965020
# rep       4.000000
# ymodel    0.963245
# ybms      0.965289
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.963500  4.0  0.962361  0.963650
# 296  0.97  0.964010  4.0  0.962662  0.964200
# 297  0.98  0.964517  4.0  0.962957  0.964746
# 298  0.99  0.965020  4.0  0.963245  0.965289
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.965020  4.0  0.963245  0.965289
# 300  1.01  0.966015  4.0  0.963803  0.966363
# 301  1.02  0.966507  4.0  0.964073  0.966894
# 302  1.03  0.966995  4.0  0.964338  0.967420
# 303  1.04  0.967480  4.0  0.964597  0.967940
#       x1         y  rep    ymodel
# 299  1.0  0.308395  5.0  0.303725
# 299
# <lambdifygenerated-14409>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1 + tanh(_a1_*x1*x1**x1))**2
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14410>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (x1 + tanh(_a1_*x1*x1**x1))**2
# <lambdifygenerated-14419>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (_a5_/x1 + tanh(_a1_*_a4_**x1*x1))**2
# <lambdifygenerated-14425>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (_a5_/(_a0_ + x1**x1) + tanh(_a1_*_a4_**x1*x1))**2
# <lambdifygenerated-14426>:2: RuntimeWarning: invalid value encountered in power
#   return x1 + (_a5_/(_a0_ + x1**x1) + tanh(_a1_*_a4_**x1*x1))**2
# x1        0.990000
# y         0.308186
# rep       5.000000
# ymodel    0.303323
# ybms      0.309885
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.306999  5.0  0.302089  0.306745
# 296  0.97  0.307484  5.0  0.302504  0.307792
# 297  0.98  0.307882  5.0  0.302916  0.308840
# 298  0.99  0.308186  5.0  0.303323  0.309885
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.308186  5.0  0.303323  0.309885
# 300  1.01  0.308504  5.0  0.304123  0.311966
# 301  1.02  0.308511  5.0  0.304515  0.312998
# 302  1.03  0.308413  5.0  0.304902  0.314024
# 303  1.04  0.308207  5.0  0.305283  0.315042
#       x1         y  rep    ymodel
# 299  1.0  0.216474  6.0  0.213672
# 299
# <lambdifygenerated-14457>:2: RuntimeWarning: invalid value encountered in power
#   return x1**x1/x1
# <lambdifygenerated-14458>:2: RuntimeWarning: invalid value encountered in power
#   return x1**x1/x1
# <lambdifygenerated-14461>:2: RuntimeWarning: invalid value encountered in power
#   return (x1**3)**x1/x1
# <lambdifygenerated-14462>:2: RuntimeWarning: invalid value encountered in power
#   return (x1**3)**x1/x1
# <lambdifygenerated-14463>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(x1)**2)**x1/x1
# <lambdifygenerated-14464>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(x1)**2)**x1/x1
# <lambdifygenerated-14465>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(x1))**2)**x1/x1
# <lambdifygenerated-14466>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(x1))**2)**x1/x1
# <lambdifygenerated-14467>:2: RuntimeWarning: invalid value encountered in log
#   return (x1*tan(sin(log(x1)))**2)**x1/x1
# <lambdifygenerated-14468>:2: RuntimeWarning: invalid value encountered in log
#   return (x1*tan(sin(log(x1)))**2)**x1/x1
# <lambdifygenerated-14469>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(x1**x1)))**2)**x1/x1
# <lambdifygenerated-14470>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(x1**x1)))**2)**x1/x1
# <lambdifygenerated-14471>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**x1)))**2)**x1/x1
# <lambdifygenerated-14471>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**x1)))**2)**x1/x1
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14472>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**x1)))**2)**x1/x1
# <lambdifygenerated-14473>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(2*x1))))**2)**x1/x1
# <lambdifygenerated-14473>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(2*x1))))**2)**x1/x1
# <lambdifygenerated-14474>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(2*x1))))**2)**x1/x1
# <lambdifygenerated-14475>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + x1))))**2)**x1/x1
# <lambdifygenerated-14475>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + x1))))**2)**x1/x1
# <lambdifygenerated-14476>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + x1))))**2)**x1/x1
# <lambdifygenerated-14477>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1)))))**2)**x1/x1
# <lambdifygenerated-14477>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1)))))**2)**x1/x1
# <lambdifygenerated-14478>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1)))))**2)**x1/x1
# <lambdifygenerated-14479>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(2*x1)))))**2)**x1/x1
# <lambdifygenerated-14479>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(2*x1)))))**2)**x1/x1
# <lambdifygenerated-14480>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(2*x1)))))**2)**x1/x1
# <lambdifygenerated-14481>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(x1))))))**2)**x1/x1
# <lambdifygenerated-14481>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(x1))))))**2)**x1/x1
# <lambdifygenerated-14482>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(x1))))))**2)**x1/x1
# <lambdifygenerated-14483>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(2*x1))))))**2)**x1/x1
# <lambdifygenerated-14483>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(2*x1))))))**2)**x1/x1
# <lambdifygenerated-14484>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(2*x1))))))**2)**x1/x1
# <lambdifygenerated-14485>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(3*x1))))))**2)**x1/x1
# <lambdifygenerated-14485>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(3*x1))))))**2)**x1/x1
# <lambdifygenerated-14486>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(3*x1))))))**2)**x1/x1
# <lambdifygenerated-14487>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + 2*x1))))))**2)**x1/x1
# <lambdifygenerated-14487>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + 2*x1))))))**2)**x1/x1
# <lambdifygenerated-14488>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + 2*x1))))))**2)**x1/x1
# <lambdifygenerated-14489>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + 2*x1))))))**2)**x1/x1
# <lambdifygenerated-14490>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + 2*x1))))))**2)**x1/x1
# <lambdifygenerated-14491>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + x1**2 + x1))))))**2)**x1/x1
# <lambdifygenerated-14491>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + x1**2 + x1))))))**2)**x1/x1
# <lambdifygenerated-14492>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + x1**2 + x1))))))**2)**x1/x1
# <lambdifygenerated-14493>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + x1*x1**x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14493>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + x1*x1**x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14494>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + x1*x1**x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14494>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + x1*x1**x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14495>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + _a6_**x1*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14495>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + _a6_**x1*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14496>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + _a6_**x1*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14497>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14497>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14498>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14499>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14500>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(x1 + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14501>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(_a3_ + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14501>:2: RuntimeWarning: invalid value encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(_a3_ + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14502>:2: RuntimeWarning: divide by zero encountered in power
#   return (x1*tan(sin(log(_a7_**(_a5_ + cos(_a3_ + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14503>:2: RuntimeWarning: divide by zero encountered in power
#   return (_a0_*tan(sin(log(_a7_**(_a5_ + cos(_a3_ + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# <lambdifygenerated-14504>:2: RuntimeWarning: divide by zero encountered in power
#   return (_a0_*tan(sin(log(_a7_**(_a5_ + cos(_a3_ + tanh(_a2_ + _a6_**_a3_*x1 + x1))))))**2)**x1/x1
# x1        0.990000
# y         0.214660
# rep       6.000000
# ymodel    0.211993
# ybms      0.213989
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.209034  6.0  0.206787  0.208676
# 296  0.97  0.210941  6.0  0.208550  0.210484
# 297  0.98  0.212816  6.0  0.210286  0.212255
# 298  0.99  0.214660  6.0  0.211993  0.213989
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.214660  6.0  0.211993  0.213989
# 300  1.01  0.218258  6.0  0.215324  0.217349
# 301  1.02  0.220013  6.0  0.216950  0.218975
# 302  1.03  0.221738  6.0  0.218549  0.220566
# 303  1.04  0.223435  6.0  0.220123  0.222123
#       x1         y  rep   ymodel
# 299  1.0  0.100895  7.0  0.10195
# 299
# <lambdifygenerated-14533>:2: RuntimeWarning: invalid value encountered in power
#   return _a6_/(x1 + x1**x1 + exp(x1))
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14534>:2: RuntimeWarning: invalid value encountered in power
#   return _a6_/(x1 + x1**x1 + exp(x1))
# <lambdifygenerated-14553>:2: RuntimeWarning: invalid value encountered in power
#   return _a6_/(x1 + ((_a5_ + 3*x1)**2)**(x1*x1**x1) + exp(x1))
# <lambdifygenerated-14554>:2: RuntimeWarning: invalid value encountered in power
#   return _a6_/(x1 + ((_a5_ + 3*x1)**2)**(x1*x1**x1) + exp(x1))
# <lambdifygenerated-14559>:2: RuntimeWarning: invalid value encountered in power
#   return _a6_/(x1 + ((_a5_ + 3*x1)**2)**(_a0_**x1*_a1_) + exp(x1))
# <lambdifygenerated-14559>:2: RuntimeWarning: overflow encountered in power
#   return _a6_/(x1 + ((_a5_ + 3*x1)**2)**(_a0_**x1*_a1_) + exp(x1))
# x1        0.990000
# y         0.100968
# rep       7.000000
# ymodel    0.102013
# ybms      0.099786
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.101250  7.0  0.102238  0.100409
# 296  0.97  0.101145  7.0  0.102157  0.100197
# 297  0.98  0.101051  7.0  0.102082  0.099990
# 298  0.99  0.100968  7.0  0.102013  0.099786
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.100968  7.0  0.102013  0.099786
# 300  1.01  0.100833  7.0  0.101893  0.099390
# 301  1.02  0.100781  7.0  0.101842  0.099197
# 302  1.03  0.100740  7.0  0.101796  0.099007
# 303  1.04  0.100709  7.0  0.101755  0.098820
#       x1         y  rep    ymodel
# 299  1.0  0.826911  8.0  0.826808
# 299
# <lambdifygenerated-14617>:2: RuntimeWarning: overflow encountered in sinh
#   return x1 + (x1*(_a4_*_a5_**2*(_a5_ + x1)*tanh((x1 + sinh(x1/cos(x1)))/x1) + 2*x1)**2 + x1)**2
# <lambdifygenerated-14618>:2: RuntimeWarning: overflow encountered in sinh
#   return x1 + (x1*(_a4_*_a5_**2*(_a5_ + x1)*tanh((x1 + sinh(x1/cos(x1)))/x1) + 2*x1)**2 + x1)**2
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14637>:2: RuntimeWarning: overflow encountered in sinh
#   return x1 + (_a0_*(_a3_ + _a4_*_a5_**2*(_a5_ + x1)*tanh((_a5_**2*_a6_ + sinh(x1/cos(_a4_)))/_a1_) + x1)**2 + _a7_)**2
# <lambdifygenerated-14639>:2: RuntimeWarning: overflow encountered in sinh
#   return _a2_ + (_a0_*(_a3_ + _a4_*_a5_**2*(_a5_ + x1)*tanh((_a5_**2*_a6_ + sinh(x1/cos(_a4_)))/_a1_) + x1)**2 + _a7_)**2
# <lambdifygenerated-14643>:2: RuntimeWarning: overflow encountered in sinh
#   return _a2_ + (_a0_*(_a3_ + _a4_*_a5_**2*(_a5_ + x1)*tanh((_a5_**2*_a6_ + sinh(x1/cos(_a4_)))/_a1_) + x1)**2 + _a7_)**2
# x1        0.990000
# y         0.822770
# rep       8.000000
# ymodel    0.822707
# ybms      0.822757
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.809830  8.0  0.809887  0.809871
# 296  0.97  0.814231  8.0  0.814247  0.814260
# 297  0.98  0.818544  8.0  0.818520  0.818555
# 298  0.99  0.822770  8.0  0.822707  0.822757
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.822770  8.0  0.822707  0.822757
# 300  1.01  0.830967  8.0  0.830826  0.830882
# 301  1.02  0.834940  8.0  0.834763  0.834807
# 302  1.03  0.838832  8.0  0.838620  0.838640
# 303  1.04  0.842644  8.0  0.842398  0.842382
#       x1         y  rep    ymodel
# 299  1.0  0.855859  9.0  0.856456
# 299
# <lambdifygenerated-14695>:2: RuntimeWarning: invalid value encountered in power
#   return sin((x1*tan(x1*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a6_/x1 + x1**x1 + cos(_a7_)))) + x1) + x1)/x1)
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14696>:2: RuntimeWarning: invalid value encountered in power
#   return sin((x1*tan(x1*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a6_/x1 + x1**x1 + cos(_a7_)))) + x1) + x1)/x1)
# <lambdifygenerated-14697>:2: RuntimeWarning: invalid value encountered in power
#   return sin((x1*tan(x1*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a0_**x1 + _a6_/x1 + cos(_a7_)))) + x1) + x1)/x1)
# <lambdifygenerated-14701>:2: RuntimeWarning: invalid value encountered in power
#   return sin((x1*tan(x1**2*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a0_**x1 + _a6_/x1 + cos(_a7_)))) + x1) + x1)/x1)
# <lambdifygenerated-14709>:2: RuntimeWarning: invalid value encountered in power
#   return sin((x1*tan(_a6_*(_a2_ + x1**x1)*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a0_**x1 + _a6_/x1 + cos(_a7_)))) + x1) + x1)/x1)
# <lambdifygenerated-14710>:2: RuntimeWarning: invalid value encountered in power
#   return sin((x1*tan(_a6_*(_a2_ + x1**x1)*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a0_**x1 + _a6_/x1 + cos(_a7_)))) + x1) + x1)/x1)
# <lambdifygenerated-14719>:2: RuntimeWarning: invalid value encountered in power
#   return sin((_a1_*tan(_a2_**2 + _a6_*(_a1_**x1 + _a2_)*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a0_**x1 + _a6_/x1 + cos(_a7_))))) + x1)/x1)
# <lambdifygenerated-14721>:2: RuntimeWarning: invalid value encountered in power
#   return sin((_a1_*tan(_a2_**2 + _a6_*(_a1_**x1 + _a2_)*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a0_**x1 + _a6_/x1 + cos(_a7_))))) + _a7_)/x1)
# <lambdifygenerated-14723>:2: RuntimeWarning: invalid value encountered in power
#   return sin((_a1_*tan(_a2_**2 + _a6_*(_a1_**x1 + _a2_)*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a0_**x1 + _a6_/x1 + cos(_a7_))))) + _a7_)/_a4_)
# <lambdifygenerated-14727>:2: RuntimeWarning: invalid value encountered in power
#   return sin((_a1_*tan(_a2_**2 + _a6_*(_a1_**x1 + _a2_)*(_a5_ + tanh(x1*(_a3_ + _a7_)*(_a0_**x1 + _a6_/x1 + cos(_a7_))))) + _a7_)/_a4_)
# x1        0.990000
# y         0.854589
# rep       9.000000
# ymodel    0.855337
# ybms      0.854592
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.850763  9.0  0.851829  0.850776
# 296  0.97  0.852043  9.0  0.853025  0.852054
# 297  0.98  0.853318  9.0  0.854194  0.853326
# 298  0.99  0.854589  9.0  0.855337  0.854592
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.854589  9.0  0.855337  0.854592
# 300  1.01  0.857128  9.0  0.857550  0.857118
# 301  1.02  0.858398  9.0  0.858621  0.858380
# 302  1.03  0.859672  9.0  0.859668  0.859644
# 303  1.04  0.860951  9.0  0.860694  0.860911
# <lambdifygenerated-14747>:2: RuntimeWarning: invalid value encountered in power
#   return sin(x1*exp((x1 + tanh(x1*x1**x1))/x1))
# <lambdifygenerated-14748>:2: RuntimeWarning: invalid value encountered in power
#   return sin(x1*exp((x1 + tanh(x1*x1**x1))/x1))
#       x1         y  rep    ymodel
# 299  1.0  0.987559  0.0  1.009541
# 299
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-14783>:2: RuntimeWarning: overflow encountered in exp
#   return sin(x1*exp((x1 + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))/x1))
# <lambdifygenerated-14783>:2: RuntimeWarning: invalid value encountered in sin
#   return sin(x1*exp((x1 + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))/x1))
# <lambdifygenerated-14787>:2: RuntimeWarning: invalid value encountered in power
#   return sin(x1*exp(x1**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14788>:2: RuntimeWarning: invalid value encountered in power
#   return sin(x1*exp(x1**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14789>:2: RuntimeWarning: overflow encountered in power
#   return sin(x1*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14789>:2: RuntimeWarning: overflow encountered in multiply
#   return sin(x1*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14793>:2: RuntimeWarning: overflow encountered in power
#   return sin(x1**2*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14794>:2: RuntimeWarning: overflow encountered in power
#   return sin(x1**2*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14795>:2: RuntimeWarning: overflow encountered in power
#   return sin(_a3_**2*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14796>:2: RuntimeWarning: overflow encountered in power
#   return sin(_a3_**2*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14797>:2: RuntimeWarning: overflow encountered in power
#   return sin(_a3_**2*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14798>:2: RuntimeWarning: overflow encountered in power
#   return sin(_a3_**2*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14799>:2: RuntimeWarning: overflow encountered in power
#   return sin(_a3_**2*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# <lambdifygenerated-14800>:2: RuntimeWarning: overflow encountered in power
#   return sin(_a3_**2*exp(_a5_**(-x1)*(_a0_ + tanh(_a7_*exp(-sin(_a4_ + x1 - tanh(_a1_*x1 - _a2_)))**(_a4_*_a7_)))))
# x1        0.990000
# y         0.987001
# rep       0.000000
# ymodel    1.008380
# ybms      0.985902
# Name: 298, dtype: float64
# ...
# 298  0.99  0.880685  1.0  0.874341  0.98683
# 300  1.01  0.866445  1.0  0.869656  0.98683
# 301  1.02  0.859324  1.0  0.867379  0.98683
# 302  1.03  0.852204  1.0  0.865144  0.98683
# 303  1.04  0.845084  1.0  0.862951  0.98683
#       x1         y  rep    ymodel
# 299  1.0  0.997841  2.0  0.949816
# 299
# x1        0.990000
# y         0.997507
# rep       2.000000
# ymodel    0.950893
# ybms      1.058953
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.996505  2.0  0.954238  1.053747
# 296  0.97  0.996839  2.0  0.953103  1.055482
# 297  0.98  0.997173  2.0  0.951988  1.057218
# 298  0.99  0.997507  2.0  0.950893  1.058953
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.997507  2.0  0.950893  1.058953
# 300  1.01  0.998175  2.0  0.948759  1.062423
# 301  1.02  0.998509  2.0  0.947720  1.064158
# 302  1.03  0.998843  2.0  0.946700  1.065894
# 303  1.04  0.999177  2.0  0.945696  1.067629
#       x1        y  rep    ymodel
# 299  1.0  0.68802  3.0  0.729184
# 299
# x1        0.990000
# y         0.691193
# rep       3.000000
# ymodel    0.730851
# ybms      0.926203
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.703097  3.0  0.736116  0.926203
# 296  0.97  0.698626  3.0  0.734316  0.926203
# 297  0.98  0.694542  3.0  0.732561  0.926203
# 298  0.99  0.691193  3.0  0.730851  0.926203
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.691193  3.0  0.730851  0.926203
# 300  1.01  0.684868  3.0  0.727559  0.926203
# 301  1.02  0.681715  3.0  0.725974  0.926203
# 302  1.03  0.678562  3.0  0.724428  0.926203
# 303  1.04  0.675409  3.0  0.722920  0.926203
#       x1         y  rep    ymodel
# 299  1.0  0.662045  4.0  0.522204
# 299
# x1        0.990000
# y         0.659711
# rep       4.000000
# ymodel    0.522706
# ybms      0.724494
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.652708  4.0  0.524305  0.724494
# 296  0.97  0.655042  4.0  0.523756  0.724494
# 297  0.98  0.657377  4.0  0.523223  0.724494
# 298  0.99  0.659711  4.0  0.522706  0.724494
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.659711  4.0  0.522706  0.724494
# 300  1.01  0.664379  4.0  0.521717  0.724494
# 301  1.02  0.665291  4.0  0.521243  0.724494
# 302  1.03  0.665850  4.0  0.520783  0.724494
# 303  1.04  0.666410  4.0  0.520335  0.724494
#       x1         y  rep    ymodel
# 299  1.0  0.955931  5.0  0.972879
# 299
# x1        0.990000
# y         0.957298
# rep       5.000000
# ymodel    0.972072
# ybms      0.912745
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.961401  5.0  0.969565  0.912745
# 296  0.97  0.960033  5.0  0.970415  0.912745
# 297  0.98  0.958666  5.0  0.971251  0.912745
# 298  0.99  0.957298  5.0  0.972072  0.912745
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.957298  5.0  0.972072  0.912745
# 300  1.01  0.954564  5.0  0.973672  0.912745
# 301  1.02  0.953196  5.0  0.974453  0.912745
# 302  1.03  0.951829  5.0  0.975220  0.912745
# 303  1.04  0.950461  5.0  0.975975  0.912745
#       x1         y  rep    ymodel
# 299  1.0  0.428688  6.0  0.703111
# 299
# x1        0.990000
# y         0.427351
# rep       6.000000
# ymodel    0.694958
# ybms      0.561933
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.423342  6.0  0.670199  0.556117
# 296  0.97  0.424678  6.0  0.678497  0.558056
# 297  0.98  0.426015  6.0  0.686751  0.559995
# 298  0.99  0.427351  6.0  0.694958  0.561933
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.427351  6.0  0.694958  0.561933
# 300  1.01  0.430024  6.0  0.711207  0.565811
# 301  1.02  0.431360  6.0  0.719240  0.567749
# 302  1.03  0.432697  6.0  0.727207  0.569688
# 303  1.04  0.434033  6.0  0.735104  0.571627
#       x1         y  rep    ymodel
# 299  1.0  0.174574  7.0  0.201082
# 299
# x1        0.990000
# y         0.171699
# rep       7.000000
# ymodel    0.193419
# ybms      0.141117
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.163074  7.0  0.170248  0.132694
# 296  0.97  0.165949  7.0  0.177996  0.135473
# 297  0.98  0.168824  7.0  0.185722  0.138280
# 298  0.99  0.171699  7.0  0.193419  0.141117
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.171699  7.0  0.193419  0.141117
# 300  1.01  0.177449  7.0  0.208704  0.146876
# 301  1.02  0.180324  7.0  0.216280  0.149799
# 302  1.03  0.183199  7.0  0.223806  0.152751
# 303  1.04  0.186074  7.0  0.231275  0.155731
#       x1         y  rep   ymodel
# 299  1.0  0.261882  8.0  0.28755
# 299
# x1        0.990000
# y         0.259714
# rep       8.000000
# ymodel    0.291721
# ybms      0.208182
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.252977  8.0  0.301426  0.208182
# 296  0.97  0.255379  8.0  0.298702  0.208182
# 297  0.98  0.257547  8.0  0.295452  0.208182
# 298  0.99  0.259714  8.0  0.291721  0.208182
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.259714  8.0  0.291721  0.208182
# 300  1.01  0.264050  8.0  0.282977  0.208182
# 301  1.02  0.266217  8.0  0.278038  0.208182
# 302  1.03  0.268385  8.0  0.272767  0.208182
# 303  1.04  0.270553  8.0  0.267194  0.208182
#       x1        y  rep    ymodel
# 299  1.0  0.64211  9.0  0.695188
# 299
# x1        0.990000
# y         0.643610
# rep       9.000000
# ymodel    0.711881
# ybms      0.907436
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.648111  9.0  0.760856  0.907436
# 296  0.97  0.646611  9.0  0.744799  0.907436
# 297  0.98  0.645111  9.0  0.728443  0.907436
# 298  0.99  0.643610  9.0  0.711881  0.907436
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.643610  9.0  0.711881  0.907436
# 300  1.01  0.640609  9.0  0.678431  0.907436
# 301  1.02  0.639109  9.0  0.661666  0.907436
# 302  1.03  0.637608  9.0  0.644943  0.907436
# 303  1.04  0.636108  9.0  0.628302  0.907436
#       x1         y  rep    ymodel
# 299  1.0  0.361254  0.0  0.243723
# 299
# x1        0.990000
# y         0.359472
# rep       0.000000
# ymodel    0.242935
# ybms      0.125206
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.354126  0.0  0.240561  0.125206
# 296  0.97  0.355908  0.0  0.241354  0.125206
# 297  0.98  0.357690  0.0  0.242145  0.125206
# 298  0.99  0.359472  0.0  0.242935  0.125206
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.359472  0.0  0.242935  0.125206
# 300  1.01  0.363036  0.0  0.244509  0.125206
# 301  1.02  0.364818  0.0  0.245293  0.125206
# 302  1.03  0.366600  0.0  0.246076  0.125206
# 303  1.04  0.368382  0.0  0.246857  0.125206
#       x1         y  rep    ymodel
# 299  1.0  0.873565  1.0  0.901149
# 299
# x1        0.990000
# y         0.880685
# rep       1.000000
# ymodel    0.900986
# ybms      0.943023
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.899489  1.0  0.900339  0.943023
# 296  0.97  0.894926  1.0  0.900580  0.943023
# 297  0.98  0.887806  1.0  0.900796  0.943023
# 298  0.99  0.880685  1.0  0.900986  0.943023
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.880685  1.0  0.900986  0.943023
# 300  1.01  0.866445  1.0  0.901285  0.943023
# 301  1.02  0.859324  1.0  0.901394  0.943023
# 302  1.03  0.852204  1.0  0.901477  0.943023
# 303  1.04  0.845084  1.0  0.901534  0.943023
#       x1         y  rep    ymodel
# 299  1.0  0.997841  2.0  1.009623
# 299
# <lambdifygenerated-27965>:2: RuntimeWarning: invalid value encountered in power
#   return x1**x1
# <lambdifygenerated-27966>:2: RuntimeWarning: invalid value encountered in power
#   return x1**x1
# x1        0.990000
# y         0.997507
# rep       2.000000
# ymodel    1.009181
# ybms      1.357710
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.996505  2.0  1.007973  1.345187
# 296  0.97  0.996839  2.0  1.008345  1.349348
# 297  0.98  0.997173  2.0  1.008752  1.353522
# 298  0.99  0.997507  2.0  1.009181  1.357710
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.997507  2.0  1.009181  1.357710
# 300  1.01  0.998175  2.0  1.010068  1.366123
# 301  1.02  0.998509  2.0  1.010510  1.370350
# 302  1.03  0.998843  2.0  1.010942  1.374589
# 303  1.04  0.999177  2.0  1.011358  1.378842
#       x1        y  rep    ymodel
# 299  1.0  0.68802  3.0  0.768073
# 299
# x1        0.990000
# y         0.691193
# rep       3.000000
# ymodel    0.768485
# ybms      0.938133
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.703097  3.0  0.770102  0.938133
# 296  0.97  0.698626  3.0  0.769487  0.938133
# 297  0.98  0.694542  3.0  0.768952  0.938133
# 298  0.99  0.691193  3.0  0.768485  0.938133
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.691193  3.0  0.768485  0.938133
# 300  1.01  0.684868  3.0  0.767707  0.938133
# 301  1.02  0.681715  3.0  0.767378  0.938133
# 302  1.03  0.678562  3.0  0.767077  0.938133
# 303  1.04  0.675409  3.0  0.766797  0.938133
#       x1         y  rep    ymodel
# 299  1.0  0.662045  4.0  0.638758
# 299
# <lambdifygenerated-27993>:2: RuntimeWarning: invalid value encountered in power
#   return _a7_*x1**x1
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/ann_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-27994>:2: RuntimeWarning: invalid value encountered in power
#   return _a7_*x1**x1
# <lambdifygenerated-27995>:2: RuntimeWarning: invalid value encountered in power
#   return _a1_**x1*_a7_
# x1        0.990000
# y         0.659711
# rep       4.000000
# ymodel    0.636670
# ybms      0.504875
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.652708  4.0  0.627342  0.508470
# 296  0.97  0.655042  4.0  0.630990  0.507269
# 297  0.98  0.657377  4.0  0.634090  0.506070
# 298  0.99  0.659711  4.0  0.636670  0.504875
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.659711  4.0  0.636670  0.504875
# 300  1.01  0.664379  4.0  0.640384  0.502492
# 301  1.02  0.665291  4.0  0.641579  0.501305
# 302  1.03  0.665850  4.0  0.642370  0.500121
# 303  1.04  0.666410  4.0  0.642785  0.498940
#       x1         y  rep    ymodel
# 299  1.0  0.955931  5.0  1.159256
# 299
# x1        0.990000
# y         0.957298
# rep       5.000000
# ymodel    1.145766
# ybms      0.978339
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.961401  5.0  1.095513  0.978339
# 296  0.97  0.960033  5.0  1.113960  0.978339
# 297  0.98  0.958666  5.0  1.130691  0.978339
# 298  0.99  0.957298  5.0  1.145766  0.978339
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.957298  5.0  1.145766  0.978339
# 300  1.01  0.954564  5.0  1.171236  0.978339
# 301  1.02  0.953196  5.0  1.181783  0.978339
# 302  1.03  0.951829  5.0  1.190977  0.978339
# 303  1.04  0.950461  5.0  1.198895  0.978339
#       x1         y  rep    ymodel
# 299  1.0  0.428688  6.0  0.306941
# 299
# x1        0.990000
# y         0.427351
# rep       6.000000
# ymodel    0.300494
# ybms      0.267335
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.423342  6.0  0.273320  0.267335
# 296  0.97  0.424678  6.0  0.283716  0.267335
# 297  0.98  0.426015  6.0  0.292765  0.267335
# 298  0.99  0.427351  6.0  0.300494  0.267335
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.427351  6.0  0.300494  0.267335
# 300  1.01  0.430024  6.0  0.312152  0.267335
# 301  1.02  0.431360  6.0  0.316181  0.267335
# 302  1.03  0.432697  6.0  0.319081  0.267335
# 303  1.04  0.434033  6.0  0.320911  0.267335
#       x1         y  rep    ymodel
# 299  1.0  0.174574  7.0 -0.060909
# 299
# x1        0.990000
# y         0.171699
# rep       7.000000
# ymodel    0.065852
# ybms      0.112894
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.163074  7.0  0.257980  0.106155
# 296  0.97  0.165949  7.0  0.230043  0.108378
# 297  0.98  0.168824  7.0  0.164490  0.110625
# 298  0.99  0.171699  7.0  0.065852  0.112894
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.171699  7.0  0.065852  0.112894
# 300  1.01  0.177449  7.0 -0.210851  0.117501
# 301  1.02  0.180324  7.0 -0.379222  0.119839
# 302  1.03  0.183199  7.0 -0.561524  0.122201
# 303  1.04  0.186074  7.0 -0.753561  0.124585
#       x1         y  rep    ymodel
# 299  1.0  0.261882  8.0  0.264866
# 299
# x1        0.990000
# y         0.259714
# rep       8.000000
# ymodel    0.202718
# ybms      0.211312
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.252977  8.0  0.054874  0.211312
# 296  0.97  0.255379  8.0  0.082434  0.211312
# 297  0.98  0.257547  8.0  0.137238  0.211312
# 298  0.99  0.259714  8.0  0.202718  0.211312
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.259714  8.0  0.202718  0.211312
# 300  1.01  0.264050  8.0  0.314074  0.211312
# 301  1.02  0.266217  8.0  0.344853  0.211312
# 302  1.03  0.268385  8.0  0.354822  0.211312
# 303  1.04  0.270553  8.0  0.343688  0.211312
#       x1        y  rep   ymodel
# 299  1.0  0.64211  9.0  0.60483
# 299
# x1        0.990000
# y         0.643610
# rep       9.000000
# ymodel    0.706904
# ybms      0.900935
# Name: 298, dtype: float64
# interpolation
#        x1         y  rep    ymodel      ybms
# 295  0.96  0.648111  9.0  0.836756  0.900935
# 296  0.97  0.646611  9.0  0.836066  0.900935
# 297  0.98  0.645111  9.0  0.791484  0.900935
# 298  0.99  0.643610  9.0  0.706904  0.900935
# extrapolation
#        x1         y  rep    ymodel      ybms
# 298  0.99  0.643610  9.0  0.706904  0.900935
# 300  1.01  0.640609  9.0  0.513756  0.900935
# 301  1.02  0.639109  9.0  0.450154  0.900935
# 302  1.03  0.637608  9.0  0.412654  0.900935
# 303  1.04  0.636108  9.0  0.389132  0.900935
#      sigma    function  mae_nn_interp.  mae_nn_extrap.  mae_mdl_interp.  \
# 0      0.0        tanh        0.009377        0.056586         0.001137
# 1      0.0        tanh        0.010359        0.025727         0.002827
# 2      0.0        tanh        0.004791        0.082387         0.000997
# 3      0.0        tanh        0.001278        0.071855         0.000314
# 4      0.0        tanh        0.002132        0.012803         0.000165
# ..     ...         ...             ...             ...              ...
# 655    0.2  leaky_ReLU        0.053171        0.152207         0.008551
# 656    0.2  leaky_ReLU        0.101135        0.534835         0.124834
# 657    0.2  leaky_ReLU        0.089813        4.210644         0.035055
# 658    0.2  leaky_ReLU        0.119849        2.947992         0.102439
# 659    0.2  leaky_ReLU        0.126252        4.911472         0.089813
#
#      mae_mdl_extrap.  rmse_nn_interp.  rmse_nn_extrap.  rmse_mdl_interp.  \
# 0           0.009393         0.012386         0.060146          0.001340
# 1           0.309184         0.012122         0.026266          0.003454
# 2           0.056736         0.006643         0.085908          0.001222
# 3           0.041855         0.001461         0.089270          0.000406
# 4           0.002835         0.002459         0.014093          0.000248
# ..               ...              ...              ...               ...
# 655         0.142148         0.087048         0.182138          0.010784
# 656         0.230120         0.127071         0.610832          0.142086
# 657         0.042514         0.105589         4.418359          0.041496
# 658         0.162222         0.141243         3.278076          0.114628
# 659         0.342070         0.184087         5.465539          0.110137
#
#      rmse_mdl_extrap.  n  r
# 0            0.011199  0  0
# 1            0.454497  1  0
# 2            0.069993  2  0
# 3            0.048799  3  0
# 4            0.003921  4  0
# ..                ... .. ..
# 655          0.164822  5  2
# 656          0.234066  6  2
# 657          0.046699  7  2
# 658          0.176435  8  2
# 659          0.346185  9  2
#
# [660 rows x 12 columns]
