# %%
#Set style for figures

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# --- Color palette ---
PALETTE = sns.color_palette("colorblind")

color_data = PALETTE[7]
color_noise = PALETTE[7]

colors = {
    '4e-3x': ['#fee0d2', '#deebf7'],
    '2x':    ['#fc9272', '#9ecae1'],
    '1x':    ['#de2d26', '#3182bd']
}

color_ann = colors['1x'][0]
color_bms = colors['1x'][1]
