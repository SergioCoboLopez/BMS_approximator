# %%
#This script takes every simulation with all points and calculates rmse and mae in each case

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from matplotlib.pyplot import figure
import seaborn as sns
import matplotlib.gridspec as gridspec
import ast
import sys
sys.path.append('../no_degeneracy/')
sys.path.append('../no_degeneracy/Prior/')
from mcmc import *
from parallel import *
from fit_prior import read_prior_par
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
def clean_index(dataframe):
    dataframe.set_index('Unnamed: 0', inplace=True)
    dataframe.index.name = None
    dataframe= dataframe.reset_index(drop=True)
    return dataframe

def add_bms_pred(dataframe, bms_trace, number_param, dimensions=False):

    if dimensions==True:
         VARS = ['x','y',]
         prior_par = read_prior_par('../no_degeneracy/Prior/final_prior_param_sq.named_equations.nv2.np10.2016-09-09 18:49:42.600380.dat')
    else:
        VARS = ['x',]
        prior_par = read_prior_par('../no_degeneracy/Prior/final_prior_param_sq.named_equations.nv1.np10.2017-10-18 18:07:35.089658.dat')

    try:
        x = dataframe[[c for c in VARS]].copy()
        y=dataframe.z
    except KeyError:
        print("HOLA!")

        
        VARS = ['x1',]
        x = dataframe[[c for c in VARS]].copy()
        y=dataframe.y

    

    #mdl model
    minrow = bms_trace[bms_trace.H == min(bms_trace.H)].iloc[0]
    minH, minexpr, minparvals = minrow.H, minrow.expr, ast.literal_eval(minrow.parvals)

    
    t = Tree(
        variables=list(x.columns),
        parameters=['a%d' % i for i in range(number_param)],
        x=x, y=y,
        prior_par=prior_par,
        max_size=200,
        from_string=minexpr,
    )

    t.set_par_values(deepcopy(minparvals))

    dplot = deepcopy(dataframe)
    dplot['zbms'] = t.predict(x)


    return dplot

def rows_to_remove(function_name, index_length,step):
    n0=0 #initial index
    
    if function_name=='10':
        n_points_int=int(np.sqrt(index_length))  #number of rows or columns in the grid
        n_points_row=int(n_points_int/5)

        print(n_points_int)
        print(n_points_row)
        
        for i in range(n_points_row):
            print(n0)
            a1=np.arange(n0,n0+n_points_int, step)
            #print(a1)
            #print(a1[-1])
            n0=a1[-1] + n_points_int*4 + 5
            
            try:
                approximation_indices=np.append(approximation_indices,a1)
            except NameError:
                approximation_indices=a1

    else:
        approximation_indices=np.arange(n0,n0+n_points_int, step)

    return approximation_indices

# %%
#Read NN and BMS data
#functions=['1', '5' , '7', '8', '10']

functions=['10', '1']
sigmas=[0.0, 0.02]

realizations=2
#N=9
#sigmas=[0.0, 0.02, 0.04,0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 0.18, 0.20]

runid=0
NPAR=10 #10, 20
steps=50000
interpolation_step=5

train_fraction=3/4

rmse_nn_train=[];rmse_nn_test=[]
rmse_mdl_train=[];rmse_mdl_test=[]

mae_nn_train=[];mae_nn_test=[]
mae_mdl_train=[];mae_mdl_test=[]

n_index=[];r_index=[];sigma_index=[];function_index=[]

#Put mae and rmse of each simulation (on nn and bms) in a dataframe
for function in functions:
    for sigma in sigmas:
        for r in range(realizations+1):
            
            #Save indices for dataframe
            r_index.append(r);sigma_index.append(sigma);function_index.append(function)
            
            #Read NN data: original and high resolution
            #------------------------------------------------------------------------------------------
            original_file_path='../../data/nns/nguyen/approximation/'
            model_d='NN_no_overfit_sigma_' + str(sigma) + '_r_' + str(r) + '.csv'
            d=pd.read_csv(original_file_path + model_d)

            hr_file_path='../../data/nns/nguyen/inter_extrapolation/'
            model_dhr='NN_no_overfit_inter_extrapolation_sigma_' + str(sigma) + '_r_' + str(r) + '.csv'
            dhr=pd.read_csv(hr_file_path + model_dhr)
            #------------------------------------------------------------------------------------------

            #High resolution dataset: run over functions
            #-------------------------------------------------------------
            dnhr=dhr[dhr['rep']==int(function)]
            dnhr=clean_index(dnhr)
            #-------------------------------------------------------------

            #Read BMS data
            #-------------------------------------------------------------
            trace_path='../../data/MSTraces/nguyen/'
            filename='BMS_nguyen_n_'+str(function)+'_sigma_'+str(sigma)+ '_r_' + str(r) + '_trace_'+str(steps)+'_prior_'+str(NPAR)+ '.csv'
            trace=pd.read_csv(trace_path + filename, sep=';', header=None, names=['t', 'H', 'expr', 'parvals', 'kk1', 'kk2','kk3'])
            #-------------------------------------------------------------
            
            #Add BMS prediction to high resolution dataframe
            #-------------------------------------------------------------
            #distinguish between one variable and two-variable functions
            if function=='10':
                dinterpolate=add_bms_pred(dnhr, trace, NPAR, dimensions=True)
            else:
                dinterpolate=add_bms_pred(dnhr, trace, NPAR)
            #-------------------------------------------------------------

            
            
            #Remove points of approximation from the dataset
            #-------------------------------------------------------------
            dn=d[d['rep']==int(function)]
            dn.set_index('Unnamed: 0', inplace=True)
            dn.index.name = None
            dn=dn.reset_index(drop=True)

            n_points_app=int(len(dn.index))
            n_points_int=int(len(dinterpolate.index))
            display(dn)
            display(dinterpolate)
            display(n_points_app)
            display(n_points_int)
    
            approximation_indices=rows_to_remove(function,n_points_int,interpolation_step)

            print(approximation_indices)
            test_df=dinterpolate.drop(approximation_indices)
            display(test_df)
            #~~~~~~~~~~~~~~~~~~~~~~~~~~


            #remove approximation points from interpolation raw dataset
            #n_points=int(len(dinterpolate.index))
            #index_0=0
            
            #if function=='10':
            #    rows_to_drop=[]
                #for x in 400:
                    #for y in 400:
            #    for i in range(n_points):
            #            rows_to_drop.append(np.arange(index_0,n_points,5)) #remove rows from y axis
            #            index_0=rows_to_drop[-1] + 5 #update index_0
            #            rows_to_drop.append( np.arange(index_0, index_0 + 400*4) )
            #            index_0=rows_to_drop[-1]

            #    print("I'm inside")

            #    print(rows_to_drop)
                        
            #else:
            #    rows_to_drop=np.arange(0,n_points,5)
            
            #dinterpolate=dinterpolate[dinterpolate.index % 5 != 0]
            #-------------------------------------------------------------
            
            
            #Compute and save Errors to dataframe
            #-----------------------------------------------------------------------------------------------------------------------            
            n_points=int(len(dnhr.index))
            train_size_bms=int(n_points*train_fraction)

            #print(n_points)
            

            train_size_bms=300
            
            #nn errors
            rmse_nn_train_i=root_mean_squared_error(dinterpolate.loc[:train_size_bms-1]['zmodel'],dinterpolate.loc[:train_size_bms -1]['z'])
            rmse_nn_train.append(rmse_nn_train_i)
                
            rmse_nn_test_i=root_mean_squared_error(dinterpolate.loc[train_size_bms-1:]['zmodel'],dinterpolate.loc[train_size_bms -1:]['z'])
            rmse_nn_test.append(rmse_nn_test_i)

            mae_nn_train_i=mean_absolute_error(dinterpolate.loc[:train_size_bms-1]['zmodel'],dinterpolate.loc[:train_size_bms -1]['z'])
            mae_nn_train.append(mae_nn_train_i)
            
            mae_nn_test_i=mean_absolute_error(dinterpolate.loc[train_size_bms-1:]['zmodel'],dinterpolate.loc[train_size_bms -1:]['z'])
            mae_nn_test.append(mae_nn_test_i)
        
            #bms errors
            try:
                rmse_mdl_train_i=root_mean_squared_error(dinterpolate.loc[:train_size_bms-1]['zbms'],dinterpolate.loc[:train_size_bms-1]['z'])
            except ValueError:
                rmse_mdl_train_i=np.inf
            rmse_mdl_train.append(rmse_mdl_train_i)

            try:
                rmse_mdl_test_i=root_mean_squared_error(dinterpolate.loc[train_size_bms-1:]['zbms'],dinterpolate.loc[train_size_bms-1:]['z'])
            except ValueError:
                rmse_mdl_test_i=np.inf
                    
            rmse_mdl_test.append(rmse_mdl_test_i)

            try:
                mae_mdl_train_i=mean_absolute_error(dinterpolate.loc[:train_size_bms-1]['zbms'],dinterpolate.loc[:train_size_bms-1]['z'])
            except ValueError:
                mae_mdl_train_i=np.inf
                    
            mae_mdl_train.append(mae_mdl_train_i)

            try:
                mae_mdl_test_i=mean_absolute_error(dinterpolate.loc[train_size_bms-1:]['zbms'],dinterpolate.loc[train_size_bms-1:]['z'])
            except ValueError:
                mae_mdl_test_i=np.inf
                
            mae_mdl_test.append(mae_mdl_test_i)
            #-----------------------------------------------------------------------------------------------------------------------
            

      
errors_df=pd.DataFrame({'sigma':sigma_index, 'function':function_index, 'mae_nn_interp.':mae_nn_train, 'mae_nn_extrap.':mae_nn_test, 
                        'mae_mdl_interp.':mae_mdl_train, 'mae_mdl_extrap.':mae_mdl_test, 'rmse_nn_interp.':rmse_nn_train, 
                        'rmse_nn_extrap.': rmse_nn_test, 'rmse_mdl_interp.':rmse_mdl_train, 'rmse_mdl_extrap.': rmse_mdl_test, 
                        'r': r_index})
errors_df.to_csv('../../data/TEST_all_errors_nguyen_interpolation' + '.csv')
display(errors_df)
# Out:
#            x       y         z  rep  noise   z_noise    zmodel
# 0     0.0000  0.0000  0.000000   10    0.0  0.000000  0.000955
# 1     0.0000  0.0125  0.000000   10    0.0  0.000000  0.000987
# 2     0.0000  0.0250  0.000000   10    0.0  0.000000  0.001018
# 3     0.0000  0.0375  0.000000   10    0.0  0.000000  0.001045
# 4     0.0000  0.0500  0.000000   10    0.0  0.000000  0.001071
# ...      ...     ...       ...  ...    ...       ...       ...
# 6395  0.9875  0.9375  0.888559   10    0.0  0.888559  0.926960
# 6396  0.9875  0.9500  0.885730   10    0.0  0.885730  0.924512
# 6397  0.9875  0.9625  0.882865   10    0.0  0.882865  0.922045
# 6398  0.9875  0.9750  0.879967   10    0.0  0.879967  0.919560
# 6399  0.9875  0.9875  0.877034   10    0.0  0.877034  0.917057
#
# [6400 rows x 7 columns]
#              x       y         z  rep    zmodel      zbms
# 0       0.0000  0.0000  0.000000   10  0.000955  0.000000
# 1       0.0000  0.0025  0.000000   10  0.000962  0.000000
# 2       0.0000  0.0050  0.000000   10  0.000968  0.000000
# 3       0.0000  0.0075  0.000000   10  0.000975  0.000000
# 4       0.0000  0.0100  0.000000   10  0.000981  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.920837  0.878116
# 159996  0.9975  0.9900  0.877525   10  0.920335  0.877525
# 159997  0.9975  0.9925  0.876932   10  0.919833  0.876932
# 159998  0.9975  0.9950  0.876338   10  0.919329  0.876338
# 159999  0.9975  0.9975  0.875742   10  0.918826  0.875742
#
# [160000 rows x 6 columns]
# 6400
# 160000
# 400
# 80
# 0
# 2000
# 4000
# 6000
# 8000
# 10000
# 12000
# 14000
# 16000
# 18000
# 20000
# 22000
# 24000
# 26000
# 28000
# 30000
# 32000
# 34000
# 36000
# 38000
# 40000
# 42000
# 44000
# 46000
# 48000
# 50000
# 52000
# 54000
# 56000
# 58000
# 60000
# 62000
# 64000
# 66000
# 68000
# 70000
# 72000
# 74000
# 76000
# 78000
# 80000
# 82000
# 84000
# 86000
# 88000
# 90000
# 92000
# 94000
# 96000
# 98000
# 100000
# 102000
# 104000
# 106000
# 108000
# 110000
# 112000
# 114000
# 116000
# 118000
# 120000
# 122000
# 124000
# 126000
# 128000
# 130000
# 132000
# 134000
# 136000
# 138000
# 140000
# 142000
# 144000
# 146000
# 148000
# 150000
# 152000
# 154000
# 156000
# 158000
# [     0      5     10 ... 158385 158390 158395]
#              x       y         z  rep    zmodel      zbms
# 1       0.0000  0.0025  0.000000   10  0.000962  0.000000
# 2       0.0000  0.0050  0.000000   10  0.000968  0.000000
# 3       0.0000  0.0075  0.000000   10  0.000975  0.000000
# 4       0.0000  0.0100  0.000000   10  0.000981  0.000000
# 6       0.0000  0.0150  0.000000   10  0.000994  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.920837  0.878116
# 159996  0.9975  0.9900  0.877525   10  0.920335  0.877525
# 159997  0.9975  0.9925  0.876932   10  0.919833  0.876932
# 159998  0.9975  0.9950  0.876338   10  0.919329  0.876338
# 159999  0.9975  0.9975  0.875742   10  0.918826  0.875742
#
# [153600 rows x 6 columns]
# <lambdifygenerated-483>:2: RuntimeWarning: divide by zero encountered in reciprocal
#   return x + (x*x**(-_a5_))**x
# <lambdifygenerated-483>:2: RuntimeWarning: invalid value encountered in multiply
#   return x + (x*x**(-_a5_))**x
# <lambdifygenerated-483>:2: RuntimeWarning: divide by zero encountered in power
#   return x + (x*x**(-_a5_))**x
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/nguyen_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-501>:2: RuntimeWarning: divide by zero encountered in power
#   return x*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)
# <lambdifygenerated-501>:2: RuntimeWarning: invalid value encountered in multiply
#   return x*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)
# <lambdifygenerated-511>:2: RuntimeWarning: divide by zero encountered in power
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(x*y/_a5_)
# <lambdifygenerated-511>:2: RuntimeWarning: overflow encountered in power
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(x*y/_a5_)
# <lambdifygenerated-511>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(x*y/_a5_)
# <lambdifygenerated-521>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(x))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-522>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(x))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-523>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(x**2))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-524>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(x**2))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-525>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(x**2))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-526>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(x**2))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-527>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(_a3_*x))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-528>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(_a3_*x))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-529>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-x - cos(_a3_*x) - 1)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-530>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-x - cos(_a3_*x) - 1)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-531>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(_a3_*x))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-532>:2: RuntimeWarning: invalid value encountered in divide
#   return (-2*x - cos(_a3_*x))*(x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-533>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_ - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-534>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_ - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-535>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-535>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-536>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-536>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-537>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-537>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-538>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-538>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-539>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_*x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-539>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_*x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-540>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_*x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-540>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_*x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-541>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-541>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-542>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-542>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-543>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-543>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-544>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-544>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-545>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-545>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-546>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-546>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-547>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**3)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-547>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**3)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-548>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**3)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-548>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**3)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-549>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**3)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-549>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**3)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-550>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**3)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-550>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a7_**2*x**3)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-551>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-551>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-552>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-552>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-553>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-1/2*_a6_*cos(_a2_*_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-553>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-1/2*_a6_*cos(_a2_*_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-554>:2: RuntimeWarning: divide by zero encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-1/2*_a6_*cos(_a2_*_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-554>:2: RuntimeWarning: invalid value encountered in multiply
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-1/2*_a6_*cos(_a2_*_a7_**2*x**2)/x - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-555>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/(_a0_ + x) - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-556>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/(_a0_ + x) - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-557>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/(_a0_ + _a1_) - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-558>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/(_a0_ + _a1_) - x - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-559>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/(_a0_ + _a1_) - _a7_ - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
# <lambdifygenerated-560>:2: RuntimeWarning: invalid value encountered in divide
#   return (x**_a0_ + (x*x**(-_a5_)*cos(_a6_))**_a3_)*(-_a6_*cos(_a2_*_a7_**2*x**2)/(_a0_ + _a1_) - _a7_ - cos(_a3_*x))*cos(_a3_*y/_a5_)/x
#            x       y         z  rep  noise   z_noise    zmodel
# 0     0.0000  0.0000  0.000000   10    0.0  0.000000  0.003603
# 1     0.0000  0.0125  0.000000   10    0.0  0.000000  0.003386
# 2     0.0000  0.0250  0.000000   10    0.0  0.000000  0.003179
# 3     0.0000  0.0375  0.000000   10    0.0  0.000000  0.002981
# 4     0.0000  0.0500  0.000000   10    0.0  0.000000  0.002793
# ...      ...     ...       ...  ...    ...       ...       ...
# 6395  0.9875  0.9375  0.888559   10    0.0  0.888559  0.929623
# 6396  0.9875  0.9500  0.885730   10    0.0  0.885730  0.927256
# 6397  0.9875  0.9625  0.882865   10    0.0  0.882865  0.924876
# 6398  0.9875  0.9750  0.879967   10    0.0  0.879967  0.922482
# 6399  0.9875  0.9875  0.877034   10    0.0  0.877034  0.920074
#
# [6400 rows x 7 columns]
#              x       y         z  rep    zmodel      zbms
# 0       0.0000  0.0000  0.000000   10  0.003603  0.000000
# 1       0.0000  0.0025  0.000000   10  0.003559  0.000000
# 2       0.0000  0.0050  0.000000   10  0.003515  0.000000
# 3       0.0000  0.0075  0.000000   10  0.003472  0.000000
# 4       0.0000  0.0100  0.000000   10  0.003429  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.923910  0.878116
# 159996  0.9975  0.9900  0.877525   10  0.923427  0.877525
# 159997  0.9975  0.9925  0.876932   10  0.922944  0.876932
# 159998  0.9975  0.9950  0.876338   10  0.922460  0.876338
# 159999  0.9975  0.9975  0.875742   10  0.921976  0.875742
#
# [160000 rows x 6 columns]
# 6400
# 160000
# 400
# 80
# 0
# 2000
# 4000
# 6000
# 8000
# 10000
# 12000
# 14000
# 16000
# 18000
# 20000
# 22000
# 24000
# 26000
# 28000
# 30000
# 32000
# 34000
# 36000
# 38000
# 40000
# 42000
# 44000
# 46000
# 48000
# 50000
# 52000
# 54000
# 56000
# 58000
# 60000
# 62000
# 64000
# 66000
# 68000
# 70000
# 72000
# 74000
# 76000
# 78000
# 80000
# 82000
# 84000
# 86000
# 88000
# 90000
# 92000
# 94000
# 96000
# 98000
# 100000
# 102000
# 104000
# 106000
# 108000
# 110000
# 112000
# 114000
# 116000
# 118000
# 120000
# 122000
# 124000
# 126000
# 128000
# 130000
# 132000
# 134000
# 136000
# 138000
# 140000
# 142000
# 144000
# 146000
# 148000
# 150000
# 152000
# 154000
# 156000
# 158000
# [     0      5     10 ... 158385 158390 158395]
#              x       y         z  rep    zmodel      zbms
# 1       0.0000  0.0025  0.000000   10  0.003559  0.000000
# 2       0.0000  0.0050  0.000000   10  0.003515  0.000000
# 3       0.0000  0.0075  0.000000   10  0.003472  0.000000
# 4       0.0000  0.0100  0.000000   10  0.003429  0.000000
# 6       0.0000  0.0150  0.000000   10  0.003344  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.923910  0.878116
# 159996  0.9975  0.9900  0.877525   10  0.923427  0.877525
# 159997  0.9975  0.9925  0.876932   10  0.922944  0.876932
# 159998  0.9975  0.9950  0.876338   10  0.922460  0.876338
# 159999  0.9975  0.9975  0.875742   10  0.921976  0.875742
#
# [153600 rows x 6 columns]
# <lambdifygenerated-613>:2: RuntimeWarning: divide by zero encountered in divide
#   return -x*(-_a3_/x + _a3_*sin(_a1_*x)*cos(_a7_*y)/_a4_)
# <lambdifygenerated-613>:2: RuntimeWarning: invalid value encountered in multiply
#   return -x*(-_a3_/x + _a3_*sin(_a1_*x)*cos(_a7_*y)/_a4_)
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/nguyen_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-614>:2: RuntimeWarning: divide by zero encountered in divide
#   return -x*(-_a3_/x + _a3_*sin(_a1_*x)*cos(_a7_*y)/_a4_)
# <lambdifygenerated-614>:2: RuntimeWarning: invalid value encountered in multiply
#   return -x*(-_a3_/x + _a3_*sin(_a1_*x)*cos(_a7_*y)/_a4_)
# <lambdifygenerated-615>:2: RuntimeWarning: divide by zero encountered in divide
#   return -x*(-_a3_/x**2 + _a3_*sin(_a1_*x)*cos(_a7_*y)/_a4_)
# <lambdifygenerated-615>:2: RuntimeWarning: invalid value encountered in multiply
#   return -x*(-_a3_/x**2 + _a3_*sin(_a1_*x)*cos(_a7_*y)/_a4_)
# <lambdifygenerated-616>:2: RuntimeWarning: divide by zero encountered in divide
#   return -x*(-_a3_/x**2 + _a3_*sin(_a1_*x)*cos(_a7_*y)/_a4_)
# <lambdifygenerated-616>:2: RuntimeWarning: invalid value encountered in multiply
#   return -x*(-_a3_/x**2 + _a3_*sin(_a1_*x)*cos(_a7_*y)/_a4_)
#            x       y         z  rep  noise   z_noise    zmodel
# 0     0.0000  0.0000  0.000000   10    0.0  0.000000  0.002198
# 1     0.0000  0.0125  0.000000   10    0.0  0.000000  0.002041
# 2     0.0000  0.0250  0.000000   10    0.0  0.000000  0.001888
# 3     0.0000  0.0375  0.000000   10    0.0  0.000000  0.001740
# 4     0.0000  0.0500  0.000000   10    0.0  0.000000  0.001596
# ...      ...     ...       ...  ...    ...       ...       ...
# 6395  0.9875  0.9375  0.888559   10    0.0  0.888559  0.925347
# 6396  0.9875  0.9500  0.885730   10    0.0  0.885730  0.923042
# 6397  0.9875  0.9625  0.882865   10    0.0  0.882865  0.920720
# 6398  0.9875  0.9750  0.879967   10    0.0  0.879967  0.918380
# 6399  0.9875  0.9875  0.877034   10    0.0  0.877034  0.916023
#
# [6400 rows x 7 columns]
#              x       y         z  rep    zmodel          zbms
# 0       0.0000  0.0000  0.000000   10  0.002198  2.435114e-38
# 1       0.0000  0.0025  0.000000   10  0.002166  2.435114e-38
# 2       0.0000  0.0050  0.000000   10  0.002134  2.435114e-38
# 3       0.0000  0.0075  0.000000   10  0.002103  2.435114e-38
# 4       0.0000  0.0100  0.000000   10  0.002072  2.435114e-38
# ...        ...     ...       ...  ...       ...           ...
# 159995  0.9975  0.9875  0.878116   10  0.919736  8.781162e-01
# 159996  0.9975  0.9900  0.877525   10  0.919263  8.775248e-01
# 159997  0.9975  0.9925  0.876932   10  0.918790  8.769320e-01
# 159998  0.9975  0.9950  0.876338   10  0.918317  8.763378e-01
# 159999  0.9975  0.9975  0.875742   10  0.917843  8.757422e-01
#
# [160000 rows x 6 columns]
# 6400
# 160000
# 400
# 80
# 0
# 2000
# 4000
# 6000
# 8000
# 10000
# 12000
# 14000
# 16000
# 18000
# 20000
# 22000
# 24000
# 26000
# 28000
# 30000
# 32000
# 34000
# 36000
# 38000
# 40000
# 42000
# 44000
# 46000
# 48000
# 50000
# 52000
# 54000
# 56000
# 58000
# 60000
# 62000
# 64000
# 66000
# 68000
# 70000
# 72000
# 74000
# 76000
# 78000
# 80000
# 82000
# 84000
# 86000
# 88000
# 90000
# 92000
# 94000
# 96000
# 98000
# 100000
# 102000
# 104000
# 106000
# 108000
# 110000
# 112000
# 114000
# 116000
# 118000
# 120000
# 122000
# 124000
# 126000
# 128000
# 130000
# 132000
# 134000
# 136000
# 138000
# 140000
# 142000
# 144000
# 146000
# 148000
# 150000
# 152000
# 154000
# 156000
# 158000
# [     0      5     10 ... 158385 158390 158395]
#              x       y         z  rep    zmodel          zbms
# 1       0.0000  0.0025  0.000000   10  0.002166  2.435114e-38
# 2       0.0000  0.0050  0.000000   10  0.002134  2.435114e-38
# 3       0.0000  0.0075  0.000000   10  0.002103  2.435114e-38
# 4       0.0000  0.0100  0.000000   10  0.002072  2.435114e-38
# 6       0.0000  0.0150  0.000000   10  0.002010  2.435114e-38
# ...        ...     ...       ...  ...       ...           ...
# 159995  0.9975  0.9875  0.878116   10  0.919736  8.781162e-01
# 159996  0.9975  0.9900  0.877525   10  0.919263  8.775248e-01
# 159997  0.9975  0.9925  0.876932   10  0.918790  8.769320e-01
# 159998  0.9975  0.9950  0.876338   10  0.918317  8.763378e-01
# 159999  0.9975  0.9975  0.875742   10  0.917843  8.757422e-01
#
# [153600 rows x 6 columns]
#            x       y         z  rep     noise   z_noise    zmodel
# 0     0.0000  0.0000  0.000000   10  0.001159  0.001159  0.007977
# 1     0.0000  0.0125  0.000000   10 -0.013802 -0.013802  0.007563
# 2     0.0000  0.0250  0.000000   10  0.010916  0.010916  0.007163
# 3     0.0000  0.0375  0.000000   10  0.008153  0.008153  0.006777
# 4     0.0000  0.0500  0.000000   10 -0.000131 -0.000131  0.006404
# ...      ...     ...       ...  ...       ...       ...       ...
# 6395  0.9875  0.9375  0.888559   10  0.008890  0.897449  0.912117
# 6396  0.9875  0.9500  0.885730   10  0.005471  0.891200  0.909782
# 6397  0.9875  0.9625  0.882865   10  0.031523  0.914388  0.907430
# 6398  0.9875  0.9750  0.879967   10  0.012454  0.892421  0.905061
# 6399  0.9875  0.9875  0.877034   10 -0.013126  0.863908  0.902677
#
# [6400 rows x 7 columns]
#              x       y         z  rep    zmodel      zbms
# 0       0.0000  0.0000  0.000000   10  0.007977  0.000000
# 1       0.0000  0.0025  0.000000   10  0.007893  0.000000
# 2       0.0000  0.0050  0.000000   10  0.007810  0.000000
# 3       0.0000  0.0075  0.000000   10  0.007727  0.000000
# 4       0.0000  0.0100  0.000000   10  0.007645  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.905890  0.877966
# 159996  0.9975  0.9900  0.877525   10  0.905414  0.877399
# 159997  0.9975  0.9925  0.876932   10  0.904937  0.876831
# 159998  0.9975  0.9950  0.876338   10  0.904460  0.876262
# 159999  0.9975  0.9975  0.875742   10  0.903982  0.875691
#
# [160000 rows x 6 columns]
# 6400
# 160000
# 400
# 80
# 0
# 2000
# 4000
# 6000
# 8000
# 10000
# 12000
# 14000
# 16000
# 18000
# 20000
# 22000
# 24000
# 26000
# 28000
# 30000
# 32000
# 34000
# 36000
# 38000
# 40000
# 42000
# 44000
# 46000
# 48000
# 50000
# 52000
# 54000
# 56000
# 58000
# 60000
# 62000
# 64000
# 66000
# 68000
# 70000
# 72000
# 74000
# 76000
# 78000
# 80000
# 82000
# 84000
# 86000
# 88000
# 90000
# 92000
# 94000
# 96000
# 98000
# 100000
# 102000
# 104000
# 106000
# 108000
# 110000
# 112000
# 114000
# 116000
# 118000
# 120000
# 122000
# 124000
# 126000
# 128000
# 130000
# 132000
# 134000
# 136000
# 138000
# 140000
# 142000
# 144000
# 146000
# 148000
# 150000
# 152000
# 154000
# 156000
# 158000
# [     0      5     10 ... 158385 158390 158395]
#              x       y         z  rep    zmodel      zbms
# 1       0.0000  0.0025  0.000000   10  0.007893  0.000000
# 2       0.0000  0.0050  0.000000   10  0.007810  0.000000
# 3       0.0000  0.0075  0.000000   10  0.007727  0.000000
# 4       0.0000  0.0100  0.000000   10  0.007645  0.000000
# 6       0.0000  0.0150  0.000000   10  0.007482  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.905890  0.877966
# 159996  0.9975  0.9900  0.877525   10  0.905414  0.877399
# 159997  0.9975  0.9925  0.876932   10  0.904937  0.876831
# 159998  0.9975  0.9950  0.876338   10  0.904460  0.876262
# 159999  0.9975  0.9975  0.875742   10  0.903982  0.875691
#
# [153600 rows x 6 columns]
#            x       y         z  rep     noise   z_noise    zmodel
# 0     0.0000  0.0000  0.000000   10  0.018905  0.018905  0.002373
# 1     0.0000  0.0125  0.000000   10 -0.006500 -0.006500  0.002151
# 2     0.0000  0.0250  0.000000   10  0.003889  0.003889  0.001941
# 3     0.0000  0.0375  0.000000   10 -0.043139 -0.043139  0.001742
# 4     0.0000  0.0500  0.000000   10  0.068063  0.068063  0.001555
# ...      ...     ...       ...  ...       ...       ...       ...
# 6395  0.9875  0.9375  0.888559   10 -0.019676  0.868883  0.933965
# 6396  0.9875  0.9500  0.885730   10 -0.031273  0.854457  0.931519
# 6397  0.9875  0.9625  0.882865   10  0.020432  0.903297  0.929052
# 6398  0.9875  0.9750  0.879967   10  0.010004  0.889971  0.926564
# 6399  0.9875  0.9875  0.877034   10 -0.002858  0.874176  0.924057
#
# [6400 rows x 7 columns]
#              x       y         z  rep    zmodel      zbms
# 0       0.0000  0.0000  0.000000   10  0.002373  0.000000
# 1       0.0000  0.0025  0.000000   10  0.002328  0.000000
# 2       0.0000  0.0050  0.000000   10  0.002283  0.000000
# 3       0.0000  0.0075  0.000000   10  0.002239  0.000000
# 4       0.0000  0.0100  0.000000   10  0.002195  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.928253  0.875855
# 159996  0.9975  0.9900  0.877525   10  0.927750  0.875278
# 159997  0.9975  0.9925  0.876932   10  0.927245  0.874700
# 159998  0.9975  0.9950  0.876338   10  0.926740  0.874121
# 159999  0.9975  0.9975  0.875742   10  0.926234  0.873541
#
# [160000 rows x 6 columns]
# 6400
# 160000
# 400
# 80
# 0
# 2000
# 4000
# 6000
# 8000
# 10000
# 12000
# 14000
# 16000
# 18000
# 20000
# 22000
# 24000
# 26000
# 28000
# 30000
# 32000
# 34000
# 36000
# 38000
# 40000
# 42000
# 44000
# 46000
# 48000
# 50000
# 52000
# 54000
# 56000
# 58000
# 60000
# 62000
# 64000
# 66000
# 68000
# 70000
# 72000
# 74000
# 76000
# 78000
# 80000
# 82000
# 84000
# 86000
# 88000
# 90000
# 92000
# 94000
# 96000
# 98000
# 100000
# 102000
# 104000
# 106000
# 108000
# 110000
# 112000
# 114000
# 116000
# 118000
# 120000
# 122000
# 124000
# 126000
# 128000
# 130000
# 132000
# 134000
# 136000
# 138000
# 140000
# 142000
# 144000
# 146000
# 148000
# 150000
# 152000
# 154000
# 156000
# 158000
# [     0      5     10 ... 158385 158390 158395]
#              x       y         z  rep    zmodel      zbms
# 1       0.0000  0.0025  0.000000   10  0.002328  0.000000
# 2       0.0000  0.0050  0.000000   10  0.002283  0.000000
# 3       0.0000  0.0075  0.000000   10  0.002239  0.000000
# 4       0.0000  0.0100  0.000000   10  0.002195  0.000000
# 6       0.0000  0.0150  0.000000   10  0.002108  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.928253  0.875855
# 159996  0.9975  0.9900  0.877525   10  0.927750  0.875278
# 159997  0.9975  0.9925  0.876932   10  0.927245  0.874700
# 159998  0.9975  0.9950  0.876338   10  0.926740  0.874121
# 159999  0.9975  0.9975  0.875742   10  0.926234  0.873541
#
# [153600 rows x 6 columns]
# <lambdifygenerated-685>:2: RuntimeWarning: invalid value encountered in divide
#   return sin(x)/x
# <lambdifygenerated-686>:2: RuntimeWarning: invalid value encountered in divide
#   return sin(x)/x
# <lambdifygenerated-687>:2: RuntimeWarning: invalid value encountered in divide
#   return sin(x**2)/x
# <lambdifygenerated-688>:2: RuntimeWarning: invalid value encountered in divide
#   return sin(x**2)/x
# <lambdifygenerated-689>:2: RuntimeWarning: invalid value encountered in divide
#   return sin(x**2)/x
# <lambdifygenerated-690>:2: RuntimeWarning: invalid value encountered in divide
#   return sin(x**2)/x
# <lambdifygenerated-691>:2: RuntimeWarning: invalid value encountered in divide
#   return sin(_a4_*x)/x
# /export/home/shared/Projects/ANN/Sergio/BMS_approximator/bin/nguyen_functions/../no_degeneracy/mcmc.py:654: OptimizeWarning: Covariance of the parameters could not be estimated
#   res = curve_fit(
# <lambdifygenerated-692>:2: RuntimeWarning: invalid value encountered in divide
#   return sin(_a4_*x)/x
#            x       y         z  rep     noise   z_noise    zmodel
# 0     0.0000  0.0000  0.000000   10 -0.005361 -0.005361  0.007834
# 1     0.0000  0.0125  0.000000   10 -0.000931 -0.000931  0.007560
# 2     0.0000  0.0250  0.000000   10 -0.001795 -0.001795  0.007294
# 3     0.0000  0.0375  0.000000   10 -0.020750 -0.020750  0.007035
# 4     0.0000  0.0500  0.000000   10  0.028269  0.028269  0.006784
# ...      ...     ...       ...  ...       ...       ...       ...
# 6395  0.9875  0.9375  0.888559   10 -0.050488  0.838071  0.944956
# 6396  0.9875  0.9500  0.885730   10 -0.013923  0.871807  0.942680
# 6397  0.9875  0.9625  0.882865   10 -0.006367  0.876499  0.940392
# 6398  0.9875  0.9750  0.879967   10 -0.007198  0.872768  0.938091
# 6399  0.9875  0.9875  0.877034   10  0.018945  0.895978  0.935778
#
# [6400 rows x 7 columns]
#              x       y         z  rep    zmodel      zbms
# 0       0.0000  0.0000  0.000000   10  0.007834  0.000000
# 1       0.0000  0.0025  0.000000   10  0.007778  0.000000
# 2       0.0000  0.0050  0.000000   10  0.007723  0.000000
# 3       0.0000  0.0075  0.000000   10  0.007669  0.000000
# 4       0.0000  0.0100  0.000000   10  0.007614  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.940372  0.877757
# 159996  0.9975  0.9900  0.877525   10  0.939908  0.877189
# 159997  0.9975  0.9925  0.876932   10  0.939443  0.876620
# 159998  0.9975  0.9950  0.876338   10  0.938979  0.876049
# 159999  0.9975  0.9975  0.875742   10  0.938513  0.875478
#
# [160000 rows x 6 columns]
# 6400
# 160000
# 400
# 80
# 0
# 2000
# 4000
# 6000
# 8000
# 10000
# 12000
# 14000
# 16000
# 18000
# 20000
# 22000
# 24000
# 26000
# 28000
# 30000
# 32000
# 34000
# 36000
# 38000
# 40000
# 42000
# 44000
# 46000
# 48000
# 50000
# 52000
# 54000
# 56000
# 58000
# 60000
# 62000
# 64000
# 66000
# 68000
# 70000
# 72000
# 74000
# 76000
# 78000
# 80000
# 82000
# 84000
# 86000
# 88000
# 90000
# 92000
# 94000
# 96000
# 98000
# 100000
# 102000
# 104000
# 106000
# 108000
# 110000
# 112000
# 114000
# 116000
# 118000
# 120000
# 122000
# 124000
# 126000
# 128000
# 130000
# 132000
# 134000
# 136000
# 138000
# 140000
# 142000
# 144000
# 146000
# 148000
# 150000
# 152000
# 154000
# 156000
# 158000
# [     0      5     10 ... 158385 158390 158395]
#              x       y         z  rep    zmodel      zbms
# 1       0.0000  0.0025  0.000000   10  0.007778  0.000000
# 2       0.0000  0.0050  0.000000   10  0.007723  0.000000
# 3       0.0000  0.0075  0.000000   10  0.007669  0.000000
# 4       0.0000  0.0100  0.000000   10  0.007614  0.000000
# 6       0.0000  0.0150  0.000000   10  0.007506  0.000000
# ...        ...     ...       ...  ...       ...       ...
# 159995  0.9975  0.9875  0.878116   10  0.940372  0.877757
# 159996  0.9975  0.9900  0.877525   10  0.939908  0.877189
# 159997  0.9975  0.9925  0.876932   10  0.939443  0.876620
# 159998  0.9975  0.9950  0.876338   10  0.938979  0.876049
# 159999  0.9975  0.9975  0.875742   10  0.938513  0.875478
#
# [153600 rows x 6 columns]
#         x    y         z  rep  noise   z_noise    zmodel
# 0  -1.000  0.0 -3.050000    1    0.0 -3.050000 -3.031649
# 1  -0.975  0.0 -2.862228    1    0.0 -2.862228 -2.857501
# 2  -0.950  0.0 -2.684201    1    0.0 -2.684201 -2.688153
# 3  -0.925  0.0 -2.515601    1    0.0 -2.515601 -2.524369
# 4  -0.900  0.0 -2.356110    1    0.0 -2.356110 -2.366791
# ..    ...  ...       ...  ...    ...       ...       ...
# 75  0.875  0.0  5.451660    1    0.0  5.451660  4.020268
# 76  0.900  0.0  5.790510    1    0.0  5.790510  4.132640
# 77  0.925  0.0  6.143451    1    0.0  6.143451  4.238757
# 78  0.950  0.0  6.510801    1    0.0  6.510801  4.338704
# 79  0.975  0.0  6.892878    1    0.0  6.892878  4.432626
#
# [80 rows x 7 columns]
#          x    y         z  rep    zmodel      zbms
# 0   -1.000  0.0 -3.050000    1 -3.031649 -3.050000
# 1   -0.995  0.0 -3.011651    1 -2.996476 -3.011651
# 2   -0.990  0.0 -2.973702    1 -2.961468 -2.973702
# 3   -0.985  0.0 -2.936150    1 -2.926631 -2.936150
# 4   -0.980  0.0 -2.898993    1 -2.891973 -2.898993
# ..     ...  ...       ...  ...       ...       ...
# 395  0.975  0.0  6.892878    1  4.432626  6.892878
# 396  0.980  0.0  6.971089    1  4.450703  6.971089
# 397  0.985  0.0  7.049904    1  4.468549  7.049904
# 398  0.990  0.0  7.129326    1  4.486165  7.129326
# 399  0.995  0.0  7.209357    1  4.503553  7.209357
#
# [400 rows x 6 columns]
# 80
# 400
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 83
#      80 display(n_points_app)
#      81 display(n_points_int)
# ---> 83 approximation_indices=rows_to_remove(function,n_points_int,interpolation_step)
#      85 print(approximation_indices)
#      86 test_df=dinterpolate.drop(approximation_indices)
#
# Cell In[4], line 74, in rows_to_remove(function_name, index_length, step)
#      71             approximation_indices=a1
#      73 else:
# ---> 74     approximation_indices=np.arange(n0,n0+n_points_int, step)
#      76 return approximation_indices
#
# UnboundLocalError: local variable 'n_points_int' referenced before assignment
