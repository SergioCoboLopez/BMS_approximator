# %%
import numpy as np

# %%
n_points_app=80
n_points_int=400
step=5

# %%
n0=0

# %%
for i in range(n_points_app):
    a0=np.arange(n0,n0+n_points_app, step)
    print(a0)
    print(a0[-1])
    n0=a0[-1] + n_points_app*5
    try:
        approximation_indices=np.append(approximation_indices,a0)
    except NameError:
        approximation_indices=a0

print(approximation_indices)

# %%
n1=1600

# %%
for i in range(n_points_app):
    a1=np.arange(n1,n1+n_points_int, step)
    print(a1)
    print(a1[-1])
    n1=a1[-1] + n_points_int*4 + 5
    try:
        approximation_indices_1=np.append(approximation_indices_1,a1)
    except NameError:
        approximation_indices_1=a1

print("\n")
print(approximation_indices_1)
# Out:
# [1600 1605 1610 1615 1620 1625 1630 1635 1640 1645 1650 1655 1660 1665
#  1670 1675 1680 1685 1690 1695 1700 1705 1710 1715 1720 1725 1730 1735
#  1740 1745 1750 1755 1760 1765 1770 1775 1780 1785 1790 1795 1800 1805
#  1810 1815 1820 1825 1830 1835 1840 1845 1850 1855 1860 1865 1870 1875
#  1880 1885 1890 1895 1900 1905 1910 1915 1920 1925 1930 1935 1940 1945
#  1950 1955 1960 1965 1970 1975 1980 1985 1990 1995]
# 1995
# [3600 3605 3610 3615 3620 3625 3630 3635 3640 3645 3650 3655 3660 3665
#  3670 3675 3680 3685 3690 3695 3700 3705 3710 3715 3720 3725 3730 3735
#  3740 3745 3750 3755 3760 3765 3770 3775 3780 3785 3790 3795 3800 3805
#  3810 3815 3820 3825 3830 3835 3840 3845 3850 3855 3860 3865 3870 3875
#  3880 3885 3890 3895 3900 3905 3910 3915 3920 3925 3930 3935 3940 3945
#  3950 3955 3960 3965 3970 3975 3980 3985 3990 3995]
# 3995
# [5600 5605 5610 5615 5620 5625 5630 5635 5640 5645 5650 5655 5660 5665
#  5670 5675 5680 5685 5690 5695 5700 5705 5710 5715 5720 5725 5730 5735
# ...
